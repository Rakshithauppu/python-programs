# %% [markdown]
# <a href="https://colab.research.google.com/github/Rakshithauppu/python-programs/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,7])
y=np.array([0,200])

plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,7])
y=np.array([0,200])

plt.plot(x,y,'*')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,7,0,10,6])
y=np.array([0,100,200,300,400])

plt.plot(x,y,)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,10,2,9])
plt.plot(y)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
import matplotlib.pyplot as plt
import numpy as np
x=([1,9,4,7])
y=([60,70,80,90])
plt.plot(x,y,marker='D')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=([1,9,4,7])
y=([60,70,80,90])
plt.plot(x,y,'o-.k')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=([1,9,4,7])
y=([60,70,80,90])
plt.plot(x,y,'-.k',marker='o',ms=15,mfc='hotpink')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=([1,7,0,10,6])
y=([0,100,200,300,400])
plt.plot(x,y,linestyle='dashed')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=([1,7,0,10,6])
y=([0,100,200,300,400])
plt.plot(x,y,color='hotpink')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=([1,7,0,10,6])
y=([0,100,200,300,400])
plt.plot(x,y,linewidth='4',color='m',linestyle='-.')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x1=([1,7,0,10,6])
x2=([2,5,1,8,0])
y1=([0,100,200,300,400])
y2=([0,100,200,300,400])
plt.plot(x1,y1,linestyle='-.')
plt.plot(x2,y2,linestyle='solid')
plt.title("SPORTS WATCH DATA",loc='right')
plt.xlabel("average pulse")
plt.ylabel("calorie burnage")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=([1,7,0,9,5])
y=([50,120,200,300,350])
plt.plot(x,y,color='red')
plt.title("SPORTS WATCH DATA",loc='right')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=([2,5,4,6,3])
y=([50,120,290,365,200])
plt.plot(x,y,color='black')
plt.xlabel("average pulse")
plt.ylabel("calorie burnage")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=([1,7,0,10,5])
y=([0,150,220,335,400])
plt.plot(x,y,color='blue')
plt.grid(axis='x')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 2)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 1)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2,1,1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2,1,2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#day one, the age and speed of 13 cars:
x = np.array([6,4,9,2,1,17,2,9,4,11,12,9,6])
y = np.array([95,72,89,86,116,26,107,87,94,78,77,85,86])
plt.scatter(x, y)
x = np.array([2,2,8,2,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([70,85,84,96,90,99,90,95,94,75,79,112,91,80,85])
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["rakshi", "bhavs", "dhanush", "bhanu"])
y = np.array([10, 8, 9, 9])
plt.bar(x,y, color='hotpink',width = 0.4)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["rakshi", "bhavs", "dhanush", "bhanu"])
y = np.array([10, 8, 9, 9])
plt.barh(x,y, color='black',height=0.6)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["chem","Clad","IT","C","eng","single","several","WS","VDC"])
y=np.array([64,82,76,60,67,57,41,86,53])
plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([64,82,76,60,67,57,41,86,53])
a=(["chem","Clad","IT","C","eng","single","several","WS","VDC"])
plt.pie(y,labels=a)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([64,82,76,60,67])
mylabels = ["chem","Clad","IT","C","eng"]
myexplode=[0,0,0.1,0,0]
plt.pie(y, labels = mylabels, startangle =270,explode=myexplode)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([64,82,76,60,67])
mylabels = ["chem","Clad","IT","C","eng"]
myexplode=[0,0,0.1,0,0]
plt.pie(y, labels = mylabels, startangle =270,explode=myexplode)
plt.legend(title = "Five subs:")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([64,82,76,60,67])
mylabels = ["chem","Clad","IT","C","eng"]
plt.pie(y, labels = mylabels, startangle =270,)
plt.legend(title = "Five subs:")
plt.show()
