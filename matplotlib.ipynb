# %% [markdown]
# <a href="https://colab.research.google.com/github/Rakshithauppu/python-programs/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["chem","Clad","IT","C","eng","single","several","WS","VDC"])
y=np.array([64,82,76,60,67,57,41,86,53])
plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([64,82,76,60,67,57,41,86,53])
a=(["chem","Clad","IT","C","eng","single","several","WS","VDC"])
plt.pie(y,labels=a)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()
